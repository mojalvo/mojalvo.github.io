# %% [markdown]
# Import Data

# %%
import pandas as pd

income_df = pd.read_csv("../notebooks/kaggle_income_edited.csv")
income_df.head()
# Out:
#                                                                                                                                  kaggle_income
# id      State_Name State_ab County         City       Place           Type Area_Code Lat       Lon        Mean  Median Stdev             sum_w
# 1011000 Alabama    AL       Mobile County  Chickasaw  Chickasaw city  City 251       30.77145  -88.079697 38773 30506  33101  1638.26051309172
# 1011010 Alabama    AL       Barbour County Louisville Clio city       City 334       31.708516 -85.611039 37725 19528  43789  258.017684685483
# 1011020 Alabama    AL       Shelby County  Columbiana Columbiana city City 205       33.191452 -86.615618 54606 31930  57348  926.030999750251
# 1011030 Alabama    AL       Mobile County  Satsuma    Creola city     City 251       30.874343 -88.009442 63919 52814  47707   378.11461910293

# %%
shootings_df = pd.read_csv("../notebooks/shootings.csv")
shootings_df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender      race           city state  signs_of_mental_illness threat_level  \
# 0      M     Asian        Shelton    WA                     True       attack
# 1      M     White          Aloha    OR                    False       attack
# 2      M  Hispanic        Wichita    KS                    False        other
# 3      M     White  San Francisco    CA                     True       attack
# 4      M  Hispanic          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category
# ...

# %%
new_income_df = income_df["State_Name"]
new_income_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-4dff73e1ed21> in <module>
# ...
